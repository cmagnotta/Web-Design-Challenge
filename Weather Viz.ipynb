# %%
#New visualizations for the Weather Viz HW

import pandas as pd
import numpy as np
from scipy.stats import linregress
from scipy import stats

# %%
citiesDF = pd.read_csv(r'/Users/christinemagnotta/Web-Design-Challenge/WebVisualizations/cities.csv')
print(citiesDF)
# Out:
#      City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0  jacareacanga           0      BR  1528902000        62  -6.22
# 1          1    kaitangata         100      NZ  1528905304        94 -46.28
# 2          2      goulburn          20      AU  1528905078        91 -34.75
# 3          3          lata          76      IN  1528905305        89  30.78
# 4          4    chokurdakh           0      RU  1528905306        88  70.62
# ..       ...           ...         ...     ...         ...       ...    ...
# 542      542        scalea          36      IT  1528905631       100  39.82
# 543      543    san andres          68      PH  1528905632       100  13.32
# 544      544        muisne          92      EC  1528905633        84   0.61
# 545      545           ati          20      TD  1528905633        25  13.21
# 546      546      san luis           0      AR  1528905472        53 -33.30
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
citiesDF.describe()
#Wanted to check on the column names.
# Out:
#          City_ID  Cloudiness          Date    Humidity         Lat  \
# count  547.00000  547.000000  5.470000e+02  547.000000  547.000000
# mean   273.00000   42.166362  1.528904e+09   70.349177   21.066051
# std    158.04957   35.620143  1.571072e+03   23.450997   33.360137
# min      0.00000    0.000000  1.528901e+09    5.000000  -54.810000
# 25%    136.50000    1.000000  1.528902e+09   55.500000   -5.615000
# 50%    273.00000   40.000000  1.528905e+09   74.000000   26.190000
# 75%    409.50000   75.000000  1.528905e+09   89.500000   50.035000
# max    546.00000  100.000000  1.528906e+09  100.000000   78.220000
#
#               Lng    Max Temp  Wind Speed
# count  547.000000  547.000000  547.000000
# mean    17.467495   67.870512    8.593583
# std     88.441615   16.750916    5.736229
# min   -179.170000   25.690000    0.720000
# 25%    -61.405000   55.400000    3.740000
# 50%     19.240000   70.420000    7.310000
# 75%     92.485000   79.870000   12.065000
# ...

# %%
#Temp Vs. Latitude

plt.scatter(citiesDF['Lat'], citiesDF['Max Temp'], c='olivedrab')
plt.xlabel("Latitude")
plt.ylabel("Temperature, in Farenheit")
plt.savefig("LatitudeVsTemp.png")

# %%
#Humidity (%) vs. Latitude

plt.scatter(citiesDF['Lat'], citiesDF['Humidity'], c='olivedrab')

plt.xlabel("Latitude")
plt.ylabel("Humidity, as Percentage")
plt.savefig("LatitudeVsHum.png")

# %%
plt.scatter(citiesDF['Lat'], citiesDF['Cloudiness'], c='olivedrab')

plt.xlabel("Latitude")
plt.ylabel("Cloud Cover, as Percentage")
plt.savefig("LatitudeVsCloud.png")

# %%
plt.scatter(citiesDF['Lat'], citiesDF['Wind Speed'], c='olivedrab')

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("LatitudeVsWind.png")

# %%
citiesDF.head(50)
# Out:
#     City_ID                City  Cloudiness Country        Date  Humidity  \
# 0         0        jacareacanga           0      BR  1528902000        62
# 1         1          kaitangata         100      NZ  1528905304        94
# 2         2            goulburn          20      AU  1528905078        91
# 3         3                lata          76      IN  1528905305        89
# 4         4          chokurdakh           0      RU  1528905306        88
# 5         5            martyush          92      RU  1528905306        94
# 6         6              hobart          20      AU  1528902000        87
# 7         7         broken hill           0      AU  1528905311        88
# 8         8           harnosand           0      SE  1528903200        44
# 9         9           tuatapere           0      NZ  1528905312       100
# 10       10        puerto ayora          90      EC  1528902000        69
# 11       11  havre-saint-pierre          75      CA  1528902000        58
# ...

# %%
#What do the top 10 cities look like

topCities = citiesDF.sort_values(by='Max Temp', ascending=False)

# %%
top50Cities = topCities.head(50)

# %%
plt.scatter(top50Cities['Lat'], top50Cities['Max Temp'], c='olivedrab')
plt.xlabel("Latitude")
plt.ylabel("Temperature, in Farenheit")

#In this chart, we can see that the 50 cities with the highest temperatures are
# Out:
# Text(0, 0.5, 'Temperature, in Farenheit')

# %%
top50corr = top50Cities[['Lat','Max Temp']]

# %%
top50corr.corr(method='pearson')
# Out:
#                Lat  Max Temp
# Lat       1.000000  0.197151
# Max Temp  0.197151  1.000000

# %%
plt.scatter(top50Cities['Lat'], top50Cities['Max Temp'], c='olivedrab')
x_values = top50Cities['Lat']
y_values = top50Cities['Max Temp']
plt.xlabel("Latitude")
plt.ylabel("Temperature, in Farenheit")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
plt.plot(x_values,regress_values,"r-")
